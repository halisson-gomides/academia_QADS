# %% [markdown]
# # Aula 1: Dataviz

# %% [markdown]
# ![](https://matplotlib.org/stable/_images/sphx_glr_anatomy_001.png)

# %% [markdown]
# ### Matplotlib
#
# O objetivo é mostrar os comandos básicos do matplotlib

# %% [markdown]
# ![](https://matplotlib.org/stable/_images/sphx_glr_logos2_003.png)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#Criando gráfico básico
array = np.arange(0,10,0.1)
plt.plot(array); # o ponto e virgula tira o texto e deixa só a imagem

# %%
#Criando seno
seno = np.sin(array)

plt.title('Função seno')
plt.xlabel('Eixo x')
plt.plot(seno)
plt.plot(seno*-1)
plt.show()

plt.plot(seno)
plt.show()

# %%
#mudando tamanho e tambem fazendo 2 plots no mesmo axes
figure = plt.figure(figsize=(20,10))
plt.plot(seno)
plt.plot(seno*-1)
#mostrar figura sendo salva
figure.savefig('Saida.png')

# %%
figura = plt.figure(figsize=(5,2))
#colocando o titulo
plt.title("Função Seno")
#plots de seno
plt.plot(seno)
plt.plot(seno*-1)
#colocando os eixos
plt.xlabel("Eixo X")
plt.ylabel("Eixo Y")
# Out:
# Text(0, 0.5, 'Eixo Y')

# %%
# mudando cores e estilo das linhas
plt.plot(seno,color='green',marker='o')
plt.plot(array*10,seno*-1,'r--')

# %%
# adicionando legendas
plt.plot(array*10,seno,label='Seno')
plt.plot(array*10,seno*-1,label='Coseno')
plt.xlabel("Eixo x")
plt.ylabel("valor Seno")
plt.legend()

# %%
# Adicionando legendas em posições qualquer
gridsize = (2,2)

lista = [1,2,3,4,5]
ax1 = plt.subplot2grid(gridsize,(0, 0),colspan = 2,rowspan = 1)
ax2 = plt.subplot2grid(gridsize,(1, 0))
ax3 = plt.subplot2grid(gridsize,(1, 1))

ax1.plot(seno)
ax2.plot(seno*-1)
ax3.plot(lista)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=2, sharex=True, sharey=True)
ax[0,0].plot(seno)
ax[1,0].plot(array)
ax[1,1].plot(seno*-1)

# %% [markdown]
# ### Plot (Pandas)

# %% [markdown]
# ![](https://www.kindpng.com/picc/m/574-5747046_python-pandas-logo-transparent-hd-png-download.png)

# %%
import seaborn as sns
df = sns.load_dataset('tips')

male = df[df['sex'] == 'Male']
female = df[df['sex'] == 'Female']


df['tip'].plot(kind = 'box')
#sns.boxplot(data = df,y = 'tip',x = 'sex')
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df['total_bill'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df.plot(kind='box', subplots=True);

# %%
import pandas as pd

# %%
df.plot(kind='scatter', x='total_bill', y='tip')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
plt.scatter(x = df['total_bill'],y = df['tip'])

# %%
df['sex'].value_counts().plot(kind='bar', rot=0)
# Out:
# <AxesSubplot:>

# %%
df['sex'].value_counts().sort_values().plot(kind='barh', color='y')
# Out:
# <AxesSubplot:>

# %%
df['tip'].hist(grid=False, bins=20, histtype='step')
# Out:
# <AxesSubplot:>

# %%
df['tip'].plot(kind='hist', density=True)
df['tip'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 8))

df.plot(kind='scatter', x='total_bill', y='tip', ax=ax[0,0])
df['day'].value_counts().plot(kind='barh', ax=ax[0,1])
df['total_bill'].plot(kind='kde', ax=ax[1,0])
df['tip'].plot(kind='hist', ax=ax[1,1])
plt.tight_layout()

# %% [markdown]
# ### Seaborn

# %% [markdown]
# ![](https://seaborn.pydata.org/_static/logo-wide-lightbg.svg)
